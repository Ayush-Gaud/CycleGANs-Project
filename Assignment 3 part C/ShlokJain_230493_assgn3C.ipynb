# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Train.csv")

# %%
df.head()
# Out:
#    Team1  Team2  Stadium  HostCountry Team1_Venue Team2_Venue Team1_Innings  \
# 0      5      4       37            4        Home        Away        Second
# 1      1     14       84            7     Neutral     Neutral         First
# 2      9     15       47            9        Home        Away         First
# 3      7      2      102            6        Home        Away         First
# 4      6      8       46            5        Home        Away         First
#
#   Team2_Innings MonthOfMatch  MatchWinner
# 0         First          Dec            4
# 1        Second          Sep            1
# 2        Second          Feb            9
# 3        Second          Aug            2
# 4        Second          Aug            6

# %%
df.isna().sum()
# Out:
# Team1            0
# Team2            0
# Stadium          0
# HostCountry      0
# Team1_Venue      0
# Team2_Venue      0
# Team1_Innings    0
# Team2_Innings    0
# MonthOfMatch     0
# MatchWinner      0
# dtype: int64

# %%
# c=one hot encoding
df_encoded = pd.get_dummies(df["Team1"],prefix="Team1")
df = pd.concat([df, df_encoded], axis=1)
df.drop(["Team1"], axis=1, inplace=True)
df_encoded = pd.get_dummies(df["Team2"],prefix="Team2")
df = pd.concat([df, df_encoded], axis=1)
df.drop(["Team2"], axis=1, inplace=True)
df.head()
# Out:
#    Stadium  HostCountry Team1_Venue Team2_Venue Team1_Innings Team2_Innings  \
# 0       37            4        Home        Away        Second         First
# 1       84            7     Neutral     Neutral         First        Second
# 2       47            9        Home        Away         First        Second
# 3      102            6        Home        Away         First        Second
# 4       46            5        Home        Away         First        Second
#
#   MonthOfMatch  MatchWinner  Team1_0  Team1_1  ...  Team2_6  Team2_7  Team2_8  \
# 0          Dec            4    False    False  ...    False    False    False
# 1          Sep            1    False     True  ...    False    False    False
# 2          Feb            9    False    False  ...    False    False    False
# 3          Aug            2    False    False  ...    False    False    False
# 4          Aug            6    False    False  ...    False    False     True
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2508 entries, 0 to 2507
# Data columns (total 40 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Stadium        2508 non-null   int64
#  1   HostCountry    2508 non-null   int64
#  2   Team1_Venue    2508 non-null   object
#  3   Team2_Venue    2508 non-null   object
#  4   Team1_Innings  2508 non-null   object
#  5   Team2_Innings  2508 non-null   object
#  6   MonthOfMatch   2508 non-null   object
#  7   MatchWinner    2508 non-null   int64
#  8   Team1_0        2508 non-null   bool
#  9   Team1_1        2508 non-null   bool
#  10  Team1_2        2508 non-null   bool
#  11  Team1_3        2508 non-null   bool
#  12  Team1_4        2508 non-null   bool
#  13  Team1_5        2508 non-null   bool
#  14  Team1_6        2508 non-null   bool
#  15  Team1_7        2508 non-null   bool
#  16  Team1_8        2508 non-null   bool
#  17  Team1_9        2508 non-null   bool
# ...

# %%
df.drop(["Stadium","MonthOfMatch","Team2_Innings"],axis=1,inplace=True) #dropped Innings of team2 because team1 innings are complementary, there is no new information, month of match and stadium affect wwinner negligibly

# %%
df["Team1_Innings"]=df["Team1_Innings"].apply(lambda x: x=="First")

# %%
df
# Out:
#       HostCountry Team1_Venue Team2_Venue  Team1_Innings  MatchWinner  \
# 0               4        Home        Away          False            4
# 1               7     Neutral     Neutral           True            1
# 2               9        Home        Away           True            9
# 3               6        Home        Away           True            2
# 4               5        Home        Away           True            6
# ...           ...         ...         ...            ...          ...
# 2503            3     Neutral     Neutral          False            5
# 2504            0        Home        Away           True            1
# 2505           15        Home        Away          False           14
# 2506           16        Home        Away           True           14
# 2507            0        Home        Away          False            1
#
#       Team1_0  Team1_1  Team1_2  Team1_3  Team1_4  ...  Team2_6  Team2_7  \
# ...

# %%
df["Team2_Venue"].value_counts()
# Out:
# Team2_Venue
# Away       1797
# Neutral     710
# Home          1
# Name: count, dtype: int64

# %%
df_encoded = pd.get_dummies(df["Team1_Venue"],prefix="Team1_Venue")
df = pd.concat([df, df_encoded], axis=1)
df.drop(["Team1_Venue"], axis=1, inplace=True)

df_encoded = pd.get_dummies(df["Team2_Venue"],prefix="Team2_Venue")
df = pd.concat([df, df_encoded], axis=1)
df.drop(["Team2_Venue"], axis=1, inplace=True)

df_encoded = pd.get_dummies(df["HostCountry"],prefix="HostCountry")
df = pd.concat([df, df_encoded], axis=1)
df.drop(["HostCountry"], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2508 entries, 0 to 2507
# Data columns (total 57 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Team1_Innings        2508 non-null   bool
#  1   MatchWinner          2508 non-null   int64
#  2   Team1_0              2508 non-null   bool
#  3   Team1_1              2508 non-null   bool
#  4   Team1_2              2508 non-null   bool
#  5   Team1_3              2508 non-null   bool
#  6   Team1_4              2508 non-null   bool
#  7   Team1_5              2508 non-null   bool
#  8   Team1_6              2508 non-null   bool
#  9   Team1_7              2508 non-null   bool
#  10  Team1_8              2508 non-null   bool
#  11  Team1_9              2508 non-null   bool
#  12  Team1_10             2508 non-null   bool
#  13  Team1_11             2508 non-null   bool
#  14  Team1_12             2508 non-null   bool
#  15  Team1_13             2508 non-null   bool
# ...

# %%
x = np.array(df.drop(["MatchWinner"],axis=1))
y = np.array(pd.get_dummies(df["MatchWinner"]))
x_test = x[-400:]
y_test = y[-400:]
x = x[:-400]
y = y[:-400]

# %%
x.shape
# Out:
# (2108, 56)

# %%
import tensorflow as tf
import keras
from keras import layers

model = keras.Sequential(
    [
        layers.Dense(57,activation='relu'),
        layers.Dense(200,activation='relu'),
        layers.Dense(200,activation='relu'),
        layers.Dense(16,activation='sigmoid'),
    ]
)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(x,y,epochs=30)
# Out:
# Epoch 1/30
# 66/66 [==============================] - 1s 2ms/step - loss: 2.1067 - accuracy: 0.3828
# Epoch 2/30
# 66/66 [==============================] - 0s 3ms/step - loss: 1.1135 - accuracy: 0.5987
# Epoch 3/30
# 66/66 [==============================] - 0s 2ms/step - loss: 0.8383 - accuracy: 0.6300
# Epoch 4/30
# 66/66 [==============================] - 0s 2ms/step - loss: 0.7618 - accuracy: 0.6352
# Epoch 5/30
# 66/66 [==============================] - 0s 2ms/step - loss: 0.7096 - accuracy: 0.6708
# Epoch 6/30
# 66/66 [==============================] - 0s 3ms/step - loss: 0.6958 - accuracy: 0.6632
# Epoch 7/30
# 66/66 [==============================] - 0s 2ms/step - loss: 0.6768 - accuracy: 0.6651
# Epoch 8/30
# 66/66 [==============================] - 0s 3ms/step - loss: 0.6466 - accuracy: 0.6779
# Epoch 9/30
# 66/66 [==============================] - 0s 2ms/step - loss: 0.6184 - accuracy: 0.6988
# Epoch 10/30
# ...

# %%
from sklearn.metrics import accuracy_score
accuracy_score(np.argmax(model.predict(x_test),axis=1),np.argmax(y_test,axis=1))
# Out:
# 13/13 [==============================] - 0s 2ms/step
# 0.6125
